# %% [markdown]
# # Capstone Project:
# # Model Evaluation

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import os
import string
import pickle
import math
import pydot
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.preprocessing import image
from keras.preprocessing.sequence import pad_sequences
from keras.applications.inception_v3 import InceptionV3, preprocess_input
from keras.models import Model, Sequential, load_model
from keras.layers import Input, Dense, Dropout, Flatten, Conv2D, MaxPooling2D, LSTM, Bidirectional, Embedding
from keras.layers.merge import add
from keras.utils import to_categorical, plot_model
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras import regularizers, optimizers
from nltk.translate.bleu_score import sentence_bleu

os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'
# Out:
# /Users/yannusinovich/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/yannusinovich/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/yannusinovich/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/yannusinovich/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/yannusinovich/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/yannusinovich/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /Users/yannusinovich/opt/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/yannusinovich/opt/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/yannusinovich/opt/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/yannusinovich/opt/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/yannusinovich/opt/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/yannusinovich/opt/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %% [markdown]
# ## Reload Model

# %%
def load_obj(name):
    with open('../Obj/' + name + '.pickle', 'rb') as f:
        return pickle.load(f)
    
vocab = load_obj("vocab")

# %%
vocab_size = len(vocab) + 1

# %%
pre_model = InceptionV3(weights = 'imagenet')
new_model = Model(pre_model.input, pre_model.layers[-2].output)
# Out:
# WARNING:tensorflow:From /Users/yannusinovich/opt/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /Users/yannusinovich/opt/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4074: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.

# %%
image_dict = dict()

for filename in os.listdir("../Data/Test_Photos/"):
    if filename.endswith(".jpg") or filename.endswith(".jpeg") or filename.endswith(".png"): 
        image_path = os.path.join("../Data/Test_Photos/", filename)
        # Convert all the images to size 299 x 299 as expected by the InceptionV3 Model
        img = image.load_img(image_path, target_size = (299, 299))
        # Convert PIL image to numpy array of 3-dimensions
        x = image.img_to_array(img)
        # Add one more dimension
        x = np.expand_dims(x, axis = 0)
        # preprocess images using preprocess_input() from inception module
        x = preprocess_input(x)
        feature = new_model.predict(x, verbose = 0)
        feature = np.reshape(feature, feature.shape[1])
        image_number = int(filename.split(".")[0])
        image_dict[image_number] = feature
# Out:
# WARNING:tensorflow:From /Users/yannusinovich/opt/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.

# %%
index_to_word = {}
word_to_index = {}
index = 1
for word in vocab:
    word_to_index[word] = index
    index_to_word[index] = word
    index += 1

# %%
max_length = 40

# %%
model = load_model("../Obj/final_model.h5")
# Out:
# WARNING:tensorflow:From /Users/yannusinovich/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/backend.py:3794: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %% [markdown]
# ## Predict Test Captions

# %%
def captionGenerator(a_photo, a_randomness):
    in_text = 'startseq'
    for i in range(max_length):
        sequence = [word_to_index[w] for w in in_text.split() if w in word_to_index]
        sequence = pad_sequences([sequence], maxlen = max_length)
        yhat = model.predict([a_photo, sequence], verbose = 0)
        yhat = np.random.choice((-yhat).argsort(axis = -1)[:, :a_randomness][0])
        word = index_to_word[yhat]
        in_text += ' ' + word
        if word == 'endseq':
            break
    final = in_text.split()
    final = final[1:-1]
    final = ' '.join(final)
    return final

# %%
caption_df = pd.DataFrame(columns = range(1,21), index = range(0,26))
for rand_vals in range(1,21):
    for photo_num, photo_data in image_dict.items():
        caption_df.loc[photo_num, rand_vals] = captionGenerator(photo_data.reshape(1,2048), rand_vals)
caption_df
# Out:
#                                                     1  \
# 0   the worlds largest model model museum is home ...
# 1   the worlds largest model model museum is home ...
# 2   the worlds largest model model museum is home ...
# 3   the worlds largest model model museum is home ...
# 4   the worlds largest model model museum is home ...
# 5   the worlds largest model model museum is home ...
# 6   the worlds largest model model museum is home ...
# 7   the worlds largest model model museum is home ...
# 8   the worlds largest model model museum is home ...
# 9   the worlds largest model model museum is home ...
# 10  the worlds largest model model museum is home ...
# 11  the worlds largest model model museum is home ...
# 12  the worlds largest model model museum is home ...
# 13  the worlds largest model model museum is home ...
# 14  the worlds largest model model museum is home ...
# 15  the worlds largest model model museum is home ...
# 16  the worlds largest model model museum is home ...
# 17  the worlds largest model of the roswell is hom...
# 18  the worlds largest model model museum is home ...
# 19  the worlds largest model of the roswell is hom...
# 20  the worlds largest model of the roswell is hom...
# 21  the worlds largest model model museum is home ...
# 22  the worlds largest model model museum is home ...
# 23  the worlds largest model model museum is home ...
# 24  the worlds largest model model museum is home ...
# 25  the worlds largest model model museum is home ...
#
#                                                     2  \
# 0   the largest manmade excavation and the most au...
# 1   and victor and built by the dead flesh stare i...
# 2   and victor and son joseph smith to be the worl...
# 3   and an abandoned mine in the world of this old...
# 4   and victor slated of the world and first demon...
# 5   the largest model museum in the western world ...
# 6   and an abandoned church in the world of the wi...
# 7   and victor home to the tapatía carpet age in t...
# 8   the largest exposition model in europe the old...
# 9   the worlds most famous flowers in this old tow...
# 10  and an ancient egyptian church built in an old...
# 11  the worlds most beautiful sculptures of bricab...
# 12  the worlds most beautiful sculptures and the r...
# 13  and victor slated and an abandoned church buil...
# 14  the largest collection in europe and an abando...
# 15  the worlds largest collection of curiosities o...
# 16  the largest manmade cave in the world and is t...
# 17  and the worlds most famous pagodas of an ancie...
# 18  the worlds largest model of egypts anachronist...
# 19  the worlds largest model model of egypts art o...
# 20  the largest exposition art pharmacy and in the...
# 21  the oldest structure in the world and the worl...
# 22  and the remains stranger house and library of ...
# 23  and the remains stranger house of an ancient e...
# 24  the largest exposition model of lyon the world...
# 25  and an abandoned mine in the world of the worl...
#
#                                                     3  \
# 0   this collection includes unique objects from d...
# 1   the ruins are home to one kilometer of egypts ...
# 2   the ruins that has become an infamous survivor...
# 3   the oldest continuously occupied prison in eur...
# 4   this collection of pez and curiosities odditie...
# 5   this giant is home to the worlds most importan...
# 6   the largest collection and museum dedicated en...
# 7   and an abandoned mine that was once the site f...
# 8   and an abandoned mine that once ruled by his d...
# 9   this museum devoted by by the and the dead of ...
# 10  this museum is home by hand and automata and a...
# 11  this giant is one stranger to the delight in t...
# 12  the largest collection in africa to the occult...
# 13  this giant is an homage to the incident trials...
# 14  and the worlds largest model of the sleeping i...
# 15  this collection includes unique history and hi...
# 16  and the remains strangest museum of antique od...
# 17  the oldest structure on oakland ohio river of ...
# 18  the oldest continuously occupied church in eur...
# 19  the remains strangest museum dedicated to the ...
# 20  the largest exposition reserve in europe in al...
# 21  this collection of antique store in ireland is...
# 22  and an old church and built in the heart of th...
# 23  this museum devoted to the history in world ri...
# 24  this museum dedicated by the art of dental mus...
# 25  the worlds largest tibetan park is the largest...
#
#                                                     4  \
# 0   this collection includes unique medium store s...
# 1   the remains where moses has the and of an ecce...
# 2   of the and the history that was constructed by...
# 3   an annual festival in the netherlands in rural...
# 4   an abandoned prison once the largest gnome col...
# 5   and victor slated in this museum devoted to an...
# 6   the largest manmade crater near the united kin...
# 7   this giant buddha statue is one in the new yor...
# 8   and victor built the most densely of the world...
# 9   and victor first museum in europe and one of t...
# 10  an ancient church and an old town in new zeala...
# 11  the worlds oldest collection of specimens carn...
# 12  this giant is an abandoned prison and home of ...
# 13  the largest collection and museum in africa to...
# 14  this small church has an ancient natural inspi...
# 15  an old church in this small chapel with tall a...
# 16  and the oldest church building and is the only...
# 17  and the worlds first collection museum featuri...
# 18  an abandoned prison now an ancient church on l...
# 19  the remains of an infamous ceremony that were ...
# 20  this small cemetery is the most visited fires ...
# 21  of and the most confusing site to be one mans ...
# 22  an old town in england of europe in rural gree...
# 23  of an old town in europe the ruins where commu...
# 24  this small museum houses an old lens of the an...
# 25  and and and victor by an eccentric millionaire...
#
#                                                     5  \
# 0   the ruins in this historic crypt was used for ...
# 1   museum devoted dedicated entirely from to life...
# 2   this the site in this ohio brooklyn islands la...
# 3   an ancient temple to be the home to some the f...
# 4   and built to the process for centuries and is ...
# 5   this collection includes some doctors of and a...
# 6   and an optical pylons organs and other flowers...
# 7   and an abandoned transformer station against a...
# 8   and built in an urban town in the redwood moun...
# 9   the oldest church of world of the dead were bu...
# 10  the oldest surviving structure of fame on the ...
# 11  this collection is dedicated by hand the bones...
# 12  an ancient egyptian village that was undiscove...
# 13  of an outsider artist built in this museum in ...
# 14  of this former british island is one of most t...
# 15  and built the most authentic dwellings fresco ...
# 16  this ancient village is an urban thoroughfare ...
# 17  an old airplane crash of mortar and mummies of...
# 18  and and an urban village and is home of natura...
# 19  collection in an accidental art museum featuri...
# 20  of billy most curious collection of curiositie...
# 21  of bricabrac kitsch history from the occult an...
# 22  and and victor stonehenge in this museum dedic...
# 23  an ancient greek temple and an old pharmacy se...
# 24  an outlandish shoe museum in this small chapel...
# 25  an annual shopping museum featuring some docto...
#
#                                                     6  \
# 0   museum dedicated entirely to one killer sighti...
# 1   collection devoted by the history in the count...
# 2   the remains in the city that has an important ...
# 3   this ancient temple has an old church with box...
# 4   the remains mistake and the first in the cycle...
# 5   an annual celebration celebrating the art gall...
# 6   of the most important in europe with some of i...
# 7   of an ancient american museum filled from art ...
# 8   and built to roll dollars dollars of and and k...
# 9   the remains where commuters of and and the oth...
# 10  and an optical pylon that has the remnants in ...
# 11  and is an urban legend on spooky shop is one t...
# 12  collection in one the most preserved christian...
# 13  an annual toilet and an urban heritage center ...
# 14  an outlandish astounding museum dedicated by a...
# 15  this cave once home to famous french artist co...
# 16  of an early transformer that has it smells lik...
# 17  the worlds largest salt lake has only its legs...
# 18  this giant bug was buried during wwii in the a...
# 19  the worlds first museum dedicated buddhists wh...
# 20  collection devoted and carved with varieties f...
# 21  this cave is home from some and strange and wi...
# 22  of bricabrac blood blood mortar the suburbs ci...
# 23  museum filled with globe of and the worlds sma...
# 24  of this ancient church was the worlds largest ...
# 25  this small cave is one of most unusual and tax...
#
#                                                     7  \
# 0   an annual art art gallery and home for the bon...
# 1   art museum in all that has the oldest continuo...
# 2   of this historic cemetery now hosts urban marv...
# 3   collection that has the remains of one the lar...
# 4   this collection tries its panoramic round dog ...
# 5   museum with museum filled from antique spannin...
# 6   an old world ii military town of this former w...
# 7   and the only fully functioning buddha construc...
# 8   the oldest structure operating church on oakla...
# 9   in the middle east where commuters only the de...
# 10  of antique curiosities curios spiders in tiny ...
# 11  collection devoted in both the faces of and an...
# 12  collection devoted to the achievements languag...
# 13  this collection includes pathological curiosit...
# 14  an abandoned mansion home in the heart where y...
# 15  this small church has become symbol park in re...
# 16  museum devoted dedicated back and made the his...
# 17  collection that of sleeping worship from natur...
# 18  museum of art includes objects from by his his...
# 19  the most collection collection of objects incl...
# 20  the remains where roosevelt most horrific ship...
# 21  and built and and an old church that houses th...
# 22  museum with property with bits with anthropomo...
# 23  museum of the boy bug worker worker and and an...
# 24  this cave once housed hundreds of pigeons gum ...
# 25  this former house once the first home on one b...
#
#                                                     8  \
# 0   of and an american dairy farm built with an ec...
# 1   an accidental doctors in the and of this strat...
# 2   museum of bricabrac history including taxiderm...
# 3   of and kitsch created by the stars that have h...
# 4   museum featuring some of mexicos greatest amer...
# 5   is said to take global on display the art art ...
# 6   and and mark of and this ancient greek ruins t...
# 7   and is also museum for grim collection of phar...
# 8   and is an astounding library museum with an an...
# 9   and an old town built by science in an old egy...
# 10  museum of bricabrac supercomputers of automata...
# 11  of its past to life the faces of this museum a...
# 12  the worlds smallest telescope includes mysteri...
# 13  and this small cave was the worlds tallest of ...
# 14  and is accessed in what in tokyo burger park a...
# 15  collection of medical evolution cards with ove...
# 16  and built the first of its kind to be an impos...
# 17  of and victor home by famous suicide soldier t...
# 18  the remains fathers of world and first the lar...
# 19  the oldest surviving synagogue of civic countr...
# 20  the ruins are set for its past on its trunk on...
# 21  this statue is now beautiful landscape house b...
# 22  and built and the remains that was made from d...
# 23  in its world war and and was buried on top in ...
# 24  museum celebrating american settlers in world ...
# 25  this giant bug is beautiful viewpoint ruin wit...
#
#                                                     9  \
# 0   collection celebrating and history and art by ...
# 1   art museum of curiosities curios spiders galor...
# 2   and and built built and the hunt that is actua...
# 3   collection in this museum of art in this old w...
# 4   museum filled entirely for mixture of billy of...
# 5   this ancient temple is home to an abandoned vi...
# 6   worlds fair has become home of strange acousti...
# 7   collection dedicated into the indian of and gi...
# 8   collection devoted and the art in one mans lif...
# 9   the ruins remain once revealed by by an uprisi...
# 10  home from modern devices museum of antique odd...
# 11  museum devoted in one the only authentic world...
# 12  museum filled into ancient art gallery dedicat...
# 13  and of taxidermied wonders in an inn and an op...
# 14  an urban city filled with geologic curiosities...
# 15  of taxidermied oddities are in time in the pub...
# 16  most curious automotive objects on la brighton...
# 17  worlds only museum to those things in its worl...
# 18  collection devoted by satanic powder from lotu...
# 19  of antique oddities oddities including odditie...
# 20  in one and of its mexico and is said as for fi...
# 21  museum with mammoth wonders including an aband...
# 22  collection of medical paraphernalia organs eac...
# 23  this statue has also an obscure curiosity drea...
# 24  and built built on hill the city where knows g...
# 25  the only fully cabinet house on new world war ...
#
#                                                    10  \
# 0   in northeastern new yorks oldest street has al...
# 1   ruins in an old world themed museum featuring ...
# 2   this abandoned mine fort built entirely from g...
# 3   worlds biggest portrait is said for the and is...
# 4   the last projects cemetery and built in chicag...
# 5   art museum dedicated exclusively with antique ...
# 6   collection dedicated by to exploring his remai...
# 7   this cave made from taxidermied contraptions m...
# 8   the selfmade garden house of the american hist...
# 9   of the soviet aircraft in this ancient village...
# 10  most famous in all dedicated with with ufoshap...
# 11  art oddities oddities in world in this former ...
# 12  and of bricabrac fish casts in this chicago bu...
# 13  an abandoned hospital hidden from western amer...
# 14  collection devoted devoted and the and of amat...
# 15  most beautiful forts and some old trolley stop...
# 16  an urban village in an arizona station serving...
# 17  home from hundreds to magnetic industry from a...
# 18  the first occupied functional in its mexico th...
# 19  is also an abandoned weapon site where inch of...
# 20  worlds only largest model model car has the wo...
# 21  in one hundred gardens ago completely construc...
# 22  and is also one hundred in an abandoned coal q...
# 23  of antique curiosities penny and manuscripts f...
# 24  of its history technology from the sea through...
# 25  an optical poles and includes offerings that h...
#
#                                                    11  \
# 0   and only known by the man mouse skeleton bones...
# 1   museum and collection from oddities antiques c...
# 2   this small patch in england in the world in ir...
# 3   home by an important chocolate crab in an enti...
# 4   and one doctors needs to display their own ima...
# 5   is both built and built and first largest land...
# 6   most confusing landscape give explore life wit...
# 7   is both only of the greatest truck bridge moai...
# 8   and its basement building now exists as museum...
# 9   in all all and modeled and in this historic ci...
# 10  an eccentric castle home entirely moved as the...
# 11  this statue commemorates sculptor winner peter...
# 12  museum of science created entirely entirely fo...
# 13  giant and sinister museum and park and museum ...
# 14  giant naked sculptures has dramatically in eng...
# 15  is home entirely built into glass with its own...
# 16  museum devoted for more and grim past over fif...
# 17  museum that of art art from and to your life w...
# 18  of bricabrac oldest continually and as the wor...
# 19  in new york and home and collective and collec...
# 20  an old trolley islands bridge on oakland deser...
# 21  this the site to be an escape location to have...
# 22  this giant portrait is one the last projects g...
# 23  this small park is dedicated by found and incl...
# 24  home that the remains behind womans royal was ...
# 25  giant sculpture of unique doctors widow create...
#
#                                                    12  \
# 0   collection that steps back back on display and...
# 1   the selfmade hotel was constructed in its kind...
# 2   stone age art store is home via by its related...
# 3   of billy an artists dream collective emporium ...
# 4   this massive buddha once once served by local ...
# 5   ruins for an abandoned military headquarters a...
# 6   of modern engineering sciences technology and ...
# 7   an optical illusion is hidden and breakfast fi...
# 8   museum featuring more exotic books spiders pow...
# 9   museum devoted to modern culture in the centur...
# 10  most museum celebrating acrobatics history fro...
# 11  is full from scrap sculptures of tiny in world...
# 12  collection to art art made carved out in one m...
# 13  this cave supposedly to take visitors coming o...
# 14  this massive lenin buddha once ran as an obscu...
# 15  this small park offers an homage demise of min...
# 16  ruins in this former town that had inspired th...
# 17  of antique plant housed the largest cave build...
# 18  the only fully home built for fishermen who to...
# 19  the oldest house outside world of is all in an...
# 20  mistake has to life at least overhead pools an...
# 21  home in chicago was an ancient temple in san m...
# 22  home in england in the redwood woods is also t...
# 23  home for one of this largest mammal wonders in...
# 24  home and home on hill for fishermen in the mal...
# 25  collection of natural mummy in milwaukee aires...
#
#                                                    13  \
# 0   the remains fathers who moved during mussolini...
# 1   this statue depicts and his death were turned ...
# 2   collection celebrating the life with machines ...
# 3   worlds radioactive storage theatre of antique ...
# 4   is an enormous rock art nouveau city decay tha...
# 5   museum of natural mummy bones flowers and scie...
# 6   worlds fair of electronic games housed and com...
# 7   this historic parisian outlet contains the rem...
# 8   and one one man has created in its detail dire...
# 9   and to have as its answer and other the occasi...
# 10  home dedicated in in time and home to an toe i...
# 11  museum in the middle east is all on musical tr...
# 12  worlds tallest street brings some man or their...
# 13  home to only an italian art museum with over c...
# 14  is also museum to rock light in time as well o...
# 15  is actually place and made years in time the o...
# 16  home built the last laser coinoperated water w...
# 17  house of religion de in all over years complet...
# 18  and victor once accessible through to and an i...
# 19  mistake the location in san wales that looks b...
# 20  of the occult incident and was one man from sc...
# 21  is also an amateur hospital on la was gifted h...
# 22  ruins and crown finger swing bridge on chicago...
# 23  and only the remains stranger and only mans ar...
# 24  is actually ordinary beer from the rolling poo...
# 25  home devoted devoted and and artists to resemb...
#
#                                                    14  \
# 0   and built by man king nelson to an annual role...
# 1   this ancient village boasts an oddities specim...
# 2   of the great archipelago forests with mummy th...
# 3   stone tower and built entirely to the ocean in...
# 4   most popular most frank palace and home crowne...
# 5   home celebrating this apocalyptic medieval fre...
# 6   worlds only museum devoted for more unique boo...
# 7   and an ancient phoenician monuments that hosts...
# 8   collection featuring the worlds first of our k...
# 9   in an australian jungle is actually one in new...
# 10  the largest museum outside all all devoted to ...
# 11  of taxidermied history and art by son created ...
# 12  art oddities automatons and museum from everyd...
# 13  this cave still stands tall statue has become ...
# 14  and victor first of stilloperating history is ...
# 15  house on hill atop lake surrounded into this c...
# 16  an urban ghost island on lake belgium and its ...
# 17  collection in small medical theater featuring ...
# 18  and the first suspension substation ever reloc...
# 19  ruins on leafy space museum housed from one th...
# 20  home from two jampacked pools on one night pla...
# 21  worlds oldest largest museum dedicated as grim...
# 22  this massive museum dedicated with an importan...
# 23  ruins at hill where roosevelt has home to mode...
# 24  this dynasty church is dedicated to love of mu...
# 25  ruins built from an outsider warrior of color ...
#
#                                                    15  \
# 0   most museum from both history of color france ...
# 1   an geologic objects in one hundred whirling st...
# 2   museum on street and the ruins at st capital a...
# 3   worlds fair excavated an collection and librar...
# 4   museum in the century hall home that mysteriou...
# 5   art art installations are an emporium on taxid...
# 6   this collection was made constructed completel...
# 7   is only burning by famed and musician joseph a...
# 8   of this historic structure played its traditio...
# 9   home entirely completely to to musical instrum...
# 10  museum devoted for and musical oddities art ar...
# 11  house filled on easter site to an iconic japan...
# 12  giant collection features miniature collection...
# 13  most unique mechanical illusion light tower at...
# 14  worlds most extravagant masterpiece theater th...
# 15  ruins hidden inside in southeast carolina town...
# 16  stone towers are steeped filled over torontos ...
# 17  museum where nature wonders including natural ...
# 18  giant naked giants by musician and spiritual c...
# 19  this former chapel with an annual feast that o...
# 20  and only remaining occupied and home to sweden...
# 21  of salt farm located in an odd illusion pharma...
# 22  this historic parisian quarter dates all machi...
# 23  is home in his final stronghold that were left...
# 24  of one the greatest of one killer suicide deat...
# 25  the ruins are covered on fantastic animals of ...
#
#                                                    16  \
# 0   is all at place at place as place and home bef...
# 1   stone sculptures including its shelves in one ...
# 2   stone windows to one museum and retail shop is...
# 3   museum that made is one and an austrian house ...
# 4   giant and the underworld are made and petrifie...
# 5   and this statue commemorating importance trage...
# 6   ruins on mountain on san bay the island for hi...
# 7   stone column once by hand by science for years...
# 8   home built into tiny world for amateur complet...
# 9   ruins hidden from outer virginia desert belgiu...
# 10  of russias best greats on one year its immense...
# 11  art venue to create some feline occult relics ...
# 12  home and is all but to help one giant plant ab...
# 13  mystery the final playground to local legend a...
# 14  an underground mine made of gardens wood light...
# 15  museum dedicated and homage to alan lewis game...
# 16  an outlandish church played role and legendary...
# 17  house with direct art history filled over vari...
# 18  the oldest continually tower church from brita...
# 19  museum in spain that constructed an elaborate ...
# 20  is full park where rotting wonders to an toe t...
# 21  an underground cave on chicagos national distr...
# 22  art and gallery built the final largest festiv...
# 23  ruins is in world players an eerie and museum ...
# 24  this former british city with some machines wi...
# 25  art deco pharmacy store and turned plant histo...
#
#                                                    17  \
# 0   of bricabrac motion force force training now t...
# 1   this an antique and museum tells an view out b...
# 2   in rural sweden with of and and mediums that t...
# 3   collection including antique equipment created...
# 4   and museum filled deep wonders built in this t...
# 5   this ancient city boasts rocky mountain known ...
# 6   museum in scotland city and sells artifacts di...
# 7   giant wooden head towers built as tribute repr...
# 8   home with box on tiny cemetery for truck made ...
# 9   and only hundred glass by local history that h...
# 10  the ruins are covered within miniature and cur...
# 11  the oldest cathedral built and the world holds...
# 12  in small cemetery which was constructed on lea...
# 13  of and constructed the worlds secondlargest mu...
# 14  this former dutch manor is dedicated as as nat...
# 15  and and mark childhood life of french mental l...
# 16  worlds smallest bug of local mice and puppets ...
# 17  is an eccentric artist installation filled int...
# 18  of modern sculptures organs includes natural m...
# 19  this statue marks young poets the and the and ...
# 20  of modern carpet chock rewarded the most wellp...
# 21  this historic building said to spend to and is...
# 22  most extravagant castle and of century archite...
# 23  an old pharmacy houses all of other and the wo...
# 24  museum of artifacts organs organs wood items e...
# 25  collection dedicated the natural history at hi...
#
#                                                    18  \
# 0   stone towers carved in milwaukee village in th...
# 1   giant light museum built in unique collection ...
# 2   of one the oldest chinese cathedral outside st...
# 3   of modern mummification structures found the w...
# 4   this statue of sex is all just stranger beer a...
# 5   most unique cavern used the baptist the most v...
# 6   of taxidermied sculptures and curious gardens ...
# 7   and was found of the dead galore of settlers s...
# 8   ruins that looks over and are in this collecti...
# 9   this old village lies decorated by giant salt ...
# 10  the remnants in the country of spain that fill...
# 11  in one of this museum of our color instruments...
# 12  an abandoned military institution and movie mu...
# 13  the most authentic remains remains on street o...
# 14  of ancient animals carnivorous trick skeleton ...
# 15  worlds tallest of sleeping truck started with ...
# 16  museum on its facade past with mummy doll in a...
# 17  worlds longest street islands once called monu...
# 18  is what could it hosts to to die over lincoln ...
# 19  and home at of saints breeding grave wonders a...
# 20  home and science cabinet between thousands are...
# 21  and and carved messages to an austrian and ame...
# 22  white garden for sale of automata oddities obj...
# 23  and one man can cross from your appearance mus...
# 24  of taxidermied eggs in europe estimated back a...
# 25  mystery is an astonishing unique temple hidden...
#
#                                                    19  \
# 0   an old quarter built and in rural california c...
# 1   this statue commemorates and his and son josep...
# 2   natural color and history created in one baske...
# 3   museum celebrating art from and manuscripts te...
# 4   giant collection from years century as to this...
# 5   home where confused confused fun in time of an...
# 6   an extensive gallery built on small patch vill...
# 7   white replicas this abandoned japanese bull st...
# 8   doctors trying at bottom in californian desert...
# 9   mystery in rural the adirondacks is leading sy...
# 10  and victor turned magnates once created and an...
# 11  natural rock formation filled between two othe...
# 12  giant metal factory was created for amateur dr...
# 13  house known to cliffside life in californian c...
# 14  museum dedicated as museum made from world pas...
# 15  worlds third first the largest of historic liv...
# 16  is the place on display beneath ancient oak pa...
# 17  collection features museum dedicated into worl...
# 18  ruins at hill with goat or some and funky wood...
# 19  house from of dentistry france all are housed ...
# 20  this striking house honors local who jesus boy...
# 21  the remains for fans from his head on former i...
# 22  of fifty sculptures in modern rotterdam park s...
# 23  an early pharmacy with its own world including...
# 24  mystery house park known at an aerial and with...
# 25  an annual collection about from local wax oddi...
#
#                                                    20
# 0   this historic tower of spanish cinema built du...
# 1   soul in modern city filled by globe of an aeri...
# 2   natural hot springs for antique memorabilia cr...
# 3   an extensive exhibit includes of curious books...
# 4   largest exposition pharmacy gallery containing...
# 5   of modern mechanical goods museum which also a...
# 6   largest tree dates from dental pipes buildings...
# 7   art instruments carved over glass sculptures o...
# 8   ruins carved over and two stone sculptures to ...
# 9   natural maritime farm turned bed on an ice des...
# 10  home to famous button store at place at time o...
# 11  in england and this memorial in oxford the sho...
# 12  the most museum continually operating evidence...
# 13  museum to woman artists artists of the disabil...
# 14  giant museum features recipes to the elusive f...
# 15  is also year the only thing outside to continu...
# 16  stone pillar created meters to human sleeping ...
# 17  house made in all that claimed once most museu...
# 18  and first astronomical excavation mounds and s...
# 19  mistake has an infamous survivor survivor that...
# 20  the worlds biggest park that seems from on lak...
# 21  giant and sinister statues in californian town...
# 22  collection features with some machines of flow...
# 23  an abandoned village that seems as the most po...
# 24  the subtle garden by nature evolution that loo...
# 25  stone statues and bones and science antiques c...

# %% [markdown]
# ## Load Actual Captions and Calculate Bleu Scores

# %%
bleu_df = pd.DataFrame(columns = range(1,21), index = range(0,26))
actual_caption_df = pd.read_csv("../Data/Test_Captions.csv")
actual_caption_df.drop(columns = "Filename", inplace = True)
for i in caption_df.index:
    for j in caption_df.columns:
        bleu_df.loc[i,j] = sentence_bleu(actual_caption_df.loc[i,"Caption"], caption_df.loc[i,j], weights=(1, 0, 0, 0))
bleu_df
# Out:
# /Users/yannusinovich/opt/anaconda3/lib/python3.7/site-packages/nltk/translate/bleu_score.py:523: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /Users/yannusinovich/opt/anaconda3/lib/python3.7/site-packages/nltk/translate/bleu_score.py:523: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /Users/yannusinovich/opt/anaconda3/lib/python3.7/site-packages/nltk/translate/bleu_score.py:523: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#             1          2          3          4          5          6  \
# 0    0.100457  0.0986547  0.0913043  0.0830189   0.105769  0.0795455
# 1    0.088785  0.0976744        0.1  0.0884956  0.0854701   0.107692
# 2   0.0888889  0.0881057  0.0959596  0.0900474  0.0896226   0.105263
# 3    0.087963  0.0913242  0.0840708    0.08867  0.0934579  0.0970874
# 4   0.0909091  0.0722433  0.0560472  0.0746888  0.0849057  0.0917874
# 5   0.0929204  0.0938967  0.0847458  0.0956522  0.0887097  0.0893617
# 6        0.08  0.0929204  0.0938967  0.0893617  0.0878661  0.0853659
# 7   0.0958904    0.10396   0.113402  0.0917031  0.0789474  0.0977778
# 8    0.101449    0.09375      0.105  0.0977778   0.109524  0.0897436
# 9   0.0913242  0.0934579  0.0878661  0.0961538  0.0909091  0.0974359
# 10  0.0747664  0.0769231  0.0622711       0.08  0.0807175   0.087963
# 11  0.0884956  0.0781893  0.0913242  0.0781893  0.0869565  0.0956938
# 12   0.079646  0.0782609   0.073913  0.0734694   0.081448  0.0728745
# 13  0.0840708  0.0818966  0.0900901   0.088785  0.0600707  0.0685484
# 14  0.0858369      0.105  0.0943396   0.092511  0.0862069  0.0843373
# 15  0.0755556  0.0702479  0.0714286  0.0863636  0.0881057  0.0980392
# 16  0.0930233  0.0952381  0.0961538  0.0947867  0.0840336  0.0892019
# 17  0.0776699  0.0769231  0.0776699  0.0772947  0.0737327  0.0754717
# 18  0.0787037  0.0763052  0.0909091   0.087963  0.0947867    0.10101
# 19  0.0940594  0.0982143   0.101852   0.104762  0.0894309  0.0948276
# 20  0.0532319  0.0702479  0.0672269    0.07173   0.063745  0.0784314
# 21  0.0711111  0.0841121  0.0945274  0.0989583  0.0909091  0.0848214
# 22   0.079646  0.0808511  0.0645161  0.0849057  0.0837004  0.0917431
# 23   0.086758  0.0794979  0.0786026  0.0896226  0.0979381  0.0801688
# 24  0.0755556  0.0722433  0.0787037  0.0805085  0.0798319  0.0833333
# 25  0.0892857  0.0995025  0.0913043  0.0884956  0.0850202  0.0921053
#
#             7          8          9         10         11         12  \
# 0    0.108911  0.0941704   0.092437  0.0990566  0.0960699  0.0866142
# 1   0.0934579  0.0823045  0.0729927  0.0972222  0.0820313  0.0929204
# 2   0.0826087  0.0873362   0.087963  0.0809717  0.0931373  0.0847458
# 3   0.0877193  0.0934579  0.0990099  0.0990099  0.0900901  0.0869565
# 4   0.0865801  0.0847458  0.0882353  0.0913242        0.1  0.0935961
# 5   0.0813008   0.106796  0.0986547  0.0852713  0.0969163  0.0995475
# 6   0.0896861  0.0963303   0.093617  0.0981308  0.0850202   0.100917
# 7   0.0819672  0.0973451  0.0909091   0.100457  0.0742049  0.0991379
# 8   0.0948276   0.100478   0.114428   0.101852  0.0972222   0.101322
# 9   0.0985222   0.097561  0.0966184  0.0900901  0.0877193  0.0883721
# 10  0.0722892  0.0640569      0.075  0.0756303  0.0756303  0.0699588
# 11   0.087156  0.0892857  0.0934579  0.0990099  0.0884956    0.10101
# 12  0.0726496  0.0734694  0.0769231      0.075  0.0684411  0.0779221
# 13  0.0676157  0.0891089  0.0913462  0.0815451       0.08  0.0883721
# 14  0.0896861  0.0958904  0.0829694  0.0865801  0.0867769        0.1
# 15  0.0826446  0.0753968  0.0917874  0.0819672  0.0833333  0.0877193
# 16  0.0779221  0.0925926  0.0833333  0.0862069  0.0934579  0.0844444
# 17  0.0740741  0.0701754   0.056338  0.0669456  0.0788177  0.0717489
# 18       0.09  0.0909091  0.0952381  0.0896861   0.071161   0.084507
# 19  0.0866142   0.102679  0.0763052   0.102326   0.104265   0.103627
# 20  0.0740741  0.0686695  0.0678733  0.0720721  0.0692641  0.0769231
# 21   0.103261   0.084507  0.0875576  0.0829493  0.0825243  0.0687023
# 22  0.0808511   0.081448  0.0818966   0.081448  0.0753138  0.0875576
# 23  0.0947867       0.09  0.0943396      0.072  0.0787402  0.0825688
# 24   0.087156  0.0821918  0.0837209  0.0769231       0.09  0.0895522
# 25  0.0941704  0.0926829   0.106061  0.0813953  0.0972222    0.09375
#
#            13         14         15         16         17         18  \
# 0    0.101382   0.104762  0.0990991   0.100962   0.100962   0.100457
# 1   0.0875576  0.0798479   0.097561  0.0886076  0.0995261  0.0958904
# 2   0.0896861  0.0952381  0.0925926  0.0995025  0.0891089  0.0904762
# 3   0.0896861  0.0925926  0.0809717  0.0913242  0.0854701  0.0829876
# 4   0.0961538  0.0801688  0.0769231  0.0904762    0.10101  0.0925926
# 5   0.0881057  0.0852713  0.0849421  0.0860656   0.100962  0.0977778
# 6   0.0944206   0.107843  0.0792453  0.0963303  0.0929204  0.0921053
# 7      0.0875  0.0929204   0.102804   0.100457  0.0929204  0.0929204
# 8         0.1   0.100917   0.102804   0.105505    0.10628  0.0948276
# 9   0.0888889  0.0901288  0.0840336  0.0925926  0.0854701  0.0917874
# 10  0.0931373  0.0759494  0.0753138  0.0821918  0.0782609  0.0792952
# 11  0.0961538  0.0896226  0.0843882      0.075  0.0904977    0.10101
# 12  0.0858586  0.0674157  0.0748899  0.0805687  0.0789474  0.0792952
# 13  0.0826087  0.0934579  0.0792453   0.087963  0.0785124  0.0742188
# 14    0.10396  0.0826446  0.0905172  0.0917431  0.0840336  0.0945946
# 15  0.0865801  0.0904762  0.0810811  0.0809717  0.0888889  0.0888889
# 16  0.0956938  0.0865801  0.0763359   0.077551  0.0869565  0.0956938
# 17  0.0672269  0.0634921  0.0613027  0.0717489  0.0680851  0.0717489
# 18  0.0862069   0.086758   0.083682  0.0892857  0.0805085   0.100503
# 19   0.100457    0.10628  0.0954357  0.0833333  0.0995475  0.0974576
# 20  0.0714286  0.0821256  0.0762332  0.0821256  0.0782609  0.0747664
# 21  0.0935961  0.0884956  0.0873362  0.0943396  0.0896226  0.0821918
# 22  0.0900474  0.0892019  0.0844444  0.0727969  0.0650685  0.0803571
# 23  0.0817308  0.0849057  0.0917874  0.0813008  0.0833333  0.0985222
# 24   0.079646  0.0798319  0.0805687   0.073913  0.0753138  0.0822511
# 25  0.0961538   0.107692  0.0816327  0.0823529  0.0816327  0.0892857
#
#            19         20
# 0    0.100917  0.0901288
# 1   0.0790514  0.0904762
# 2   0.0837004  0.0769231
# 3    0.083682   0.078125
# 4   0.0952381   0.077821
# 5   0.0995261   0.093617
# 6   0.0956522  0.0860656
# 7   0.0932203   0.092437
# 8    0.107317  0.0905512
# 9   0.0909091  0.0881057
# 10  0.0829694  0.0841121
# 11  0.0793651  0.0813008
# 12  0.0729614  0.0789474
# 13  0.0813008  0.0985222
# 14    0.09375  0.0901288
# 15  0.0772201  0.0954774
# 16  0.0900901  0.0869565
# 17   0.064257  0.0683761
# 18  0.0809717  0.0772201
# 19  0.0889831   0.093617
# 20  0.0726496  0.0776256
# 21  0.0891089  0.0756303
# 22  0.0854701  0.0798319
# 23  0.0847458  0.0848214
# 24  0.0807175  0.0778689
# 25  0.0882353  0.0826446

# %%
avg_bleu_df = pd.DataFrame(columns = range(1,21), index = ["avg"])
for j in bleu_df.columns:
    avg_bleu_df.loc["avg",j] = bleu_df.loc[:,j].mean()
avg_bleu_df
# Out:
#              1          2          3          4          5          6  \
# avg  0.0848463  0.0865247  0.0860433  0.0874582  0.0862237  0.0892166
#
#              7          8          9         10         11         12  \
# avg  0.0861743  0.0878303  0.0876543  0.0867335  0.0856098  0.0885574
#
#             13         14         15         16         17         18  \
# avg  0.0897641  0.0886392  0.0848142  0.0868849  0.0870038  0.0893039
#
#             19         20
# avg  0.0862311  0.0845128

# %%
avg_bleu_df.loc["avg",:]
# Out:
# 1     0.0848463
# 2     0.0865247
# 3     0.0860433
# 4     0.0874582
# 5     0.0862237
# 6     0.0892166
# 7     0.0861743
# 8     0.0878303
# 9     0.0876543
# 10    0.0867335
# 11    0.0856098
# 12    0.0885574
# 13    0.0897641
# 14    0.0886392
# 15    0.0848142
# 16    0.0868849
# 17    0.0870038
# 18    0.0893039
# 19    0.0862311
# 20    0.0845128
# Name: avg, dtype: object

# %%
ax = avg_bleu_df.loc["avg",:].plot(kind = "bar", legend = False, figsize = (20,10))
plt.xlabel("How Many of the Top-Matching Words the Model Picks From", fontsize = 15)
plt.ylabel('Single-Word Match BLEU Score', fontsize = 15)
plt.yticks(np.arange(0,.11,.01))
plt.xticks(rotation = "horizontal")
plt.title('BLEU Scores Based on Number of Top-Matching Words', fontsize = 25)
plt.show();

# %% [markdown]
# ## Review Most Popular Words with No Randomness

# %%
for i in range(len(caption_df.loc[:,1])):
    print("Caption number " + str(i) + ": " + caption_df.loc[i,1])
# Out:
# Caption number 0: the worlds largest model model museum is home to the worlds most famous flowers and the remains of the worlds largest model of egypts egypts and the dead flesh of the shooting bug lovecraft and the occasional hungry and
# Caption number 1: the worlds largest model model museum is home to the worlds most famous flowers and the remains of the worlds largest model of egypts egypts and the regions and the worlds largest model of egypts history of the boy
# Caption number 2: the worlds largest model model museum is home to the worlds most famous flowers and the remains of the worlds largest model of egypts egypts and the dead flesh of the shooting bug lovecraft and the occasional contraptions and
# Caption number 3: the worlds largest model model museum is home to the worlds largest model of egypts history and orleans and patriotism of the french poet and the dead flesh of the proportions and of the proportions and of the middle
# Caption number 4: the worlds largest model model museum is home to the worlds most famous flowers and the remains of the worlds largest model of egypts egypts and the dead flesh of the winchester age gustav ii and first home to
# Caption number 5: the worlds largest model model museum is home to the worlds most famous flowers and the remains of the worlds largest model of egypts egypts and the dead flesh galore and the occasional bugs and the occasional contraptions and
# Caption number 6: the worlds largest model model museum is home to the worlds largest model model of the roswell is the largest crater dunes in the world and the worlds largest model model museum of electronic machines and science emporium and
# Caption number 7: the worlds largest model model museum is home to the worlds most famous flowers and the remains of the worlds largest model of egypts egypts and the dead flesh of the shooting bug lovecraft and the occasional hungry and
# Caption number 8: the worlds largest model model museum is home to the worlds most famous flowers and the remains of the worlds largest model of egypts egypts and mediums and victor and son joseph smith and is now home to the
# Caption number 9: the worlds largest model model museum is home to the worlds most famous flowers and the remains of the worlds largest model of egypts egypts and the dead flesh of the shooting bug lovecraft and the occasional hungry and
# Caption number 10: the worlds largest model model museum is home to the worlds largest model model of the roswell is the largest crater dunes in the world and the worlds largest model model museum and museum dedicated to the twin and
# Caption number 11: the worlds largest model model museum is home to the worlds most famous flowers and the remains of the worlds largest model of egypts egypts and the dead flesh galore and the occasional bugs and the occasional contraptions and
# Caption number 12: the worlds largest model model museum is home to the worlds most famous flowers and the remains of the worlds largest model of egypts egypts and the dead flesh galore and the occasional bugs and the occasional contraptions and
# Caption number 13: the worlds largest model model museum is home to the worlds most famous flowers and the remains of the worlds largest model of egypts egypts and the dead flesh galore and the occasional bugs and the occasional contraptions and
# Caption number 14: the worlds largest model model museum is home to the worlds largest model of egypts history and orleans and patriotism of the american history of the shooting bug lovecraft and the remains of the recordsetting de santiago lincoln and
# Caption number 15: the worlds largest model model museum is home to the worlds largest model model of the roswell is the largest crater dunes in the world and the worlds largest model model museum of electronic machines and science emporium and
# Caption number 16: the worlds largest model model museum is home to the worlds most famous flowers and the remains of the worlds largest model of egypts egypts and the dead flesh of the shooting flesh of the shooting bug lovecraft and
# Caption number 17: the worlds largest model of the roswell is home to the worlds largest model of egypts carpet art and curiosities positioned in the middle of the middle of the middle of the rhine of the middle of the middle
# Caption number 18: the worlds largest model model museum is home to the worlds largest model of egypts history and orleans and patriotism of the french poet and the dead flesh of the proportions and of the proportions and of the middle
# Caption number 19: the worlds largest model of the roswell is home to the worlds most famous flowers and the remains of the worlds largest model of egypts egypts and the dead flesh of the regions and the world and the and
# Caption number 20: the worlds largest model of the roswell is home to the worlds largest model of egypts carpet art art and curiosities and curiosities and curiosities and curiosities and curiosities and curiosities and curiosities and curiosities specimens curios specimens spiders
# Caption number 21: the worlds largest model model museum is home to the worlds largest model model of the roswell is the largest crater dunes in the world and the worlds largest model model museum of electronic machines and science emporium and
# Caption number 22: the worlds largest model model museum is home to the worlds most famous flowers and the remains of the worlds largest model of egypts egypts and the dead flesh galore and the occasional bugs and the occasional contraptions and
# Caption number 23: the worlds largest model model museum is home to the worlds most famous flowers and the remains of the worlds largest model of egypts egypts and the dead flesh of the shooting bug lovecraft and the occasional hungry and
# Caption number 24: the worlds largest model model museum is home to the worlds largest model model of the roswell is the largest crater dunes in the world and the worlds largest model model museum of electronic machines and science emporium and
# Caption number 25: the worlds largest model model museum is home to the worlds largest model model of the roswell is the worlds largest bioluminescent hole is the largest exposition art pharmacy in the world and the worlds largest model of the

# %% [markdown]
# ## Compare Most Popular Words Based on Randomness

# %%
caption_vocab = pd.DataFrame(columns = range(1, 21), index = ["vocab"], data = np.empty((1, 20), dtype = np.str))
caption_vocab
for i in range(0, 26):
    for j in range(1, 21):
        caption_vocab.loc["vocab", j] = caption_vocab.loc["vocab", j] + caption_df.loc[i, j]

# %%
caption_vocab
# Out:
#                                                        1  \
# vocab  the worlds largest model model museum is home ...
#
#                                                        2  \
# vocab  the largest manmade excavation and the most au...
#
#                                                        3  \
# vocab  this collection includes unique objects from d...
#
#                                                        4  \
# vocab  this collection includes unique medium store s...
#
#                                                        5  \
# vocab  the ruins in this historic crypt was used for ...
#
#                                                        6  \
# vocab  museum dedicated entirely to one killer sighti...
#
#                                                        7  \
# vocab  an annual art art gallery and home for the bon...
#
#                                                        8  \
# vocab  of and an american dairy farm built with an ec...
#
#                                                        9  \
# vocab  collection celebrating and history and art by ...
#
#                                                       10  \
# vocab  in northeastern new yorks oldest street has al...
#
#                                                       11  \
# vocab  and only known by the man mouse skeleton bones...
#
#                                                       12  \
# vocab  collection that steps back back on display and...
#
#                                                       13  \
# vocab  the remains fathers who moved during mussolini...
#
#                                                       14  \
# vocab  and built by man king nelson to an annual role...
#
#                                                       15  \
# vocab  most museum from both history of color france ...
#
#                                                       16  \
# vocab  is all at place at place as place and home bef...
#
#                                                       17  \
# vocab  of bricabrac motion force force training now t...
#
#                                                       18  \
# vocab  stone towers carved in milwaukee village in th...
#
#                                                       19  \
# vocab  an old quarter built and in rural california c...
#
#                                                       20
# vocab  this historic tower of spanish cinema built du...

# %%
for j in np.arange(1,21):
    wordstring = caption_vocab.loc["vocab", j]
    wordlist = wordstring.split()
    wordfreq = [wordlist.count(w) for w in wordlist]
    word_df = pd.DataFrame(columns = ["words", "frequencies"])
    word_df.loc[:,"words",] = wordlist
    word_df.loc[:,"frequencies"] = wordfreq
    word_df.sort_values("frequencies", ascending = False, inplace = True)
    word_df.drop_duplicates(subset = "words", inplace = True)
    top_word_df = word_df.head(10)
    newwordlist = top_word_df.loc[:,"words"]
    newwordfreq = top_word_df.loc[:,"frequencies"]
    plt.figure(figsize=(20,10)) 
    plt.bar(newwordlist, newwordfreq)
    plt.xlabel("Top Words", fontsize = 25)
    plt.ylabel('Frequency', fontsize = 25)
    plt.xticks(rotation = "horizontal", fontsize = 20)
    plt.yticks(fontsize = 20)
    plt.title(f'Most Popular Words for a Randomness of {j}', fontsize = 25)
    plt.show();
